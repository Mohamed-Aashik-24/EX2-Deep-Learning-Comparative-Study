# %% [markdown]
# # Experiment 1 - ANN for Classification
# **Name:** Mohamed Aashik S
#
# **Roll No:** 24BAD072

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
data = load_breast_cancer()
x, y = data.data, data.target

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

model = Sequential([
    Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=20, batch_size=32, validation_split=0.2)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - accuracy: 0.5495 - loss: 0.6720 - val_accuracy: 0.8022 - val_loss: 0.4965
# Epoch 2/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8571 - loss: 0.4026 - val_accuracy: 0.9121 - val_loss: 0.3128
# Epoch 3/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9176 - loss: 0.2680 - val_accuracy: 0.9341 - val_loss: 0.2269
# Epoch 4/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9313 - loss: 0.1963 - val_accuracy: 0.9451 - val_loss: 0.1823
# Epoch 5/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9478 - loss: 0.1558 - val_accuracy: 0.9451 - val_loss: 0.1555
# Epoch 6/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9505 - loss: 0.1291 - val_accuracy: 0.9670 - val_loss: 0.1383
# Epoch 7/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9670 - loss: 0.1113 - val_accuracy: 0.9780 - val_loss: 0.1244
# Epoch 8/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9863 - loss: 0.0954 - val_accuracy: 0.9890 - val_loss: 0.1159
# Epoch 9/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9863 - loss: 0.0849 - val_accuracy: 0.9890 - val_loss: 0.1090
# Epoch 10/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9890 - loss: 0.0758 - val_accuracy: 0.9890 - val_loss: 0.1037
# Epoch 11/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9890 - loss: 0.0690 - val_accuracy: 0.9890 - val_loss: 0.0993
# Epoch 12/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9863 - loss: 0.0631 - val_accuracy: 0.9890 - val_loss: 0.0956
# Epoch 13/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9890 - loss: 0.0574 - val_accuracy: 0.9890 - val_loss: 0.0924
# Epoch 14/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9890 - loss: 0.0534 - val_accuracy: 0.9890 - val_loss: 0.0898
# Epoch 15/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9890 - loss: 0.0500 - val_accuracy: 0.9890 - val_loss: 0.0872
# Epoch 16/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9890 - loss: 0.0469 - val_accuracy: 0.9890 - val_loss: 0.0843
# Epoch 17/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9890 - loss: 0.0439 - val_accuracy: 0.9890 - val_loss: 0.0830
# Epoch 18/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9890 - loss: 0.0411 - val_accuracy: 0.9780 - val_loss: 0.0813
# Epoch 19/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9890 - loss: 0.0393 - val_accuracy: 0.9780 - val_loss: 0.0809
# Epoch 20/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9890 - loss: 0.0371 - val_accuracy: 0.9780 - val_loss: 0.0788

# %%
pred = (model.predict(X_test) > 0.5).astype(int)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step

# %%
print("Accuracy:", accuracy_score(y_test, pred))
print("Precision:", precision_score(y_test, pred))
print("Recall:", recall_score(y_test, pred))
print("F1-score:", f1_score(y_test, pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, pred))
# Out:
# Accuracy: 0.9824561403508771
# Precision: 0.9859154929577465
# Recall: 0.9859154929577465
# F1-score: 0.9859154929577465
# Confusion Matrix:
#  [[42  1]
#  [ 1 70]]
